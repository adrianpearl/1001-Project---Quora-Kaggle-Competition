# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn import metrics
#from sklearn import cross_validation
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.feature_extraction import stop_words
from sklearn.metrics import f1_score
from nltk.stem.snowball import SnowballStemmer
from sklearn.utils import resample
from sklearn.metrics import precision_recall_curve

# %matplotlib inline

# %%
data = pd.read_csv('train.csv', index_col = 0)

# %%
data_small = data.sample(100000, replace = False)

# %%
stop =  stop_words.ENGLISH_STOP_WORDS
stemmer = SnowballStemmer('english')
data_stemmed = data.copy()
data_stemmed['question_text'] = [' '.join([stemmer.stem(word) for word in text.split(' ')])
          for text in data_stemmed.question_text]

# %%
def data_prep(dataset, training_split, test_split):
    X = dataset['question_text']
    Y = dataset['target']
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = training_split, test_size = test_split)
    
    return(X_train, X_test, Y_train, Y_test)


def model_vectorize(data_used, vectorizer_type, binary_type, ngram, stop_word, model_type):
    X_train = data_used[0]
    X_test = data_used[1]
    Y_train = data_used[2]
    Y_test = data_used[3]
    
    vectorizer = vectorizer_type(binary = binary_type, stop_words = stop_word, ngram_range=ngram)
    vectorizer.fit(X_train)
    X_train_vectorized = vectorizer.transform(X_train)
    X_test_vectorized = vectorizer.transform(X_test)
    model = model_type
    model.fit(X_train_vectorized, Y_train)
    
    scores = model.predict_proba(X_test_vectorized)[:,1]
    precision, recall, thresholds = precision_recall_curve(Y_test, scores)
    precision, recall = precision[:-1], recall[:-1]
    fscores = 2*np.divide(np.multiply(precision, recall), np.add(precision, recall))
    max_fscore = np.nanmax(fscores)
    ind_max = fscores.argmax() #not sure this is working
    threshold_max = thresholds[ind_max]
    
    return(max_fscore, threshold_max)


def downsample(df):
    # Separate majority and minority classes
    df_majority = df[df.target==0]
    df_minority = df[df.target==1]

    # Downsample majority class
    df_majority_downsampled = resample(df_majority, 
                                     replace=False,    # sample without replacement
                                     n_samples=df_minority.shape[0],     # to match minority class
                                     random_state=123) # reproducible results

    # Combine minority class with downsampled majority class
    df_downsampled = pd.concat([df_majority_downsampled, df_minority])
    
    return (df_downsampled)

# %%
downsample_data_regular = data_prep(downsample(data), .9, .1)
downsample_data_stemmed = data_prep(downsample(data_stemmed), .9,.1)

# %%
test = model_vectorize(downsample_data_regular, CountVectorizer, True, (1,2), None, LogisticRegression())

# %%
fscores = []
thresholds = []
fscores.append(test[0])
thresholds.append(test[1])
metrics = pd.DataFrame({'fscore': fscores, 'threshold': thresholds})
metrics.sort_values(by = ['fscore'], ascending=False)
# Out:
#      fscore  threshold
# 0  0.897366   0.431035

# %%
test2 = model_vectorize(downsample_data_regular, CountVectorizer, True, (1,2), None, BernoulliNB())

# %%
fscores = []
thresholds = []
fscores.append(test2[0])
thresholds.append(test2[1])
metrics = pd.DataFrame({'fscore': fscores, 'threshold': thresholds})
metrics.sort_values(by = ['fscore'], ascending=False)
# Out:
#      fscore  threshold
# 0  0.872824   0.041563

# %%
test3 = model_vectorize(downsample_data_stemmed, CountVectorizer, True, (1,2), None, BernoulliNB())
test4 = model_vectorize(downsample_data_regular, CountVectorizer, True, (1,3), None, BernoulliNB())
test5 = model_vectorize(downsample_data_regular, CountVectorizer, True, (1,3), stop, BernoulliNB())
test6 = model_vectorize(downsample_data_regular, TfidfVectorizer, False, (1,2), None, BernoulliNB())

# %%
fscores = []
thresholds = []
for i in [test, test2, test3, test4, test5, test6]:
    fscores.append(i[0])
    thresholds.append(i[1])
metrics = pd.DataFrame({'fscore': fscores, 'threshold': thresholds})
metrics.sort_values(by = ['fscore'], ascending=False)
# Out:
#      fscore  threshold
# 0  0.897366   0.431035
# 4  0.878318   0.004500
# 1  0.872824   0.041563
# 5  0.872824   0.041563
# 3  0.872032   0.000451
# 2  0.871758   0.037112

# %%
len(downsample_data_regular)
#data.target.value_counts()
#len(downsample_data_regular[0]), len(downsample_data_regular[1]), len(downsample_data_regular[2]), len(downsample_data_regular[3])
# Out:
# 4

# %%
#create models
dataset = [downsample_data_regular, downsample_data_stemmed]
vectorizer_type = [CountVectorizer, TfidfVectorizer]
binary_type = [True, False]
ngram = [(1,2), (1,3), (1,4)]
stop_word = [None, stop]
model_type = [LogisticRegression(), BernoulliNB()]

model_initialize = []
for h in dataset:
    for i in vectorizer_type:
        for j in binary_type:
            for k in ngram:
                for l in model_type:
                    for m in stop_word:
                        model_initialize.append(model_vectorize(h, i, j, k, m, l))
                    
#create labels
dataset_label = ['Downsample Full Regular Data', 'Downsample Full Stemmed Data']
vectorizer_type_label = ['CountV', 'TFIDV']
binary_type_label = ['T', 'F']
ngram_label = [(1,2), (1,3), (1,4)]
stop_word_label = ['None', 'english']
model_type_label = ['LR', 'NB']

labels = []
for h in dataset_label:    
    for i in vectorizer_type_label:
        for j in binary_type_label:
            for k in ngram_label:
                for l in model_type_label:
                    for m in stop_word_label:
                        label = '%s %s %s %s %s %s' %(h, i, j, k, m, l)
                        labels.append(label)
                        
fscores = []
thresholds = []
for i in model_initialize:
    fscores.append(i[0])
    thresholds.append(i[1])
metrics = pd.DataFrame({'label': labels,'fscore': fscores, 'threshold': thresholds})
metrics.sort_values(by = ['fscore'], ascending=False)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
#       fscore                                              label     threshold
# 0   0.897366  Downsample Full Regular Data CountV T (1, 2) N...  4.310353e-01
# 16  0.897256  Downsample Full Regular Data CountV F (1, 3) N...  3.812638e-01
# 4   0.896673  Downsample Full Regular Data CountV T (1, 3) N...  3.497340e-01
# 12  0.896654  Downsample Full Regular Data CountV F (1, 2) N...  4.275448e-01
# 20  0.896248  Downsample Full Regular Data CountV F (1, 4) N...  3.779705e-01
# 64  0.895887  Downsample Full Stemmed Data CountV F (1, 3) N...  4.057508e-01
# 48  0.895531  Downsample Full Stemmed Data CountV T (1, 2) N...  3.640555e-01
# 8   0.895427  Downsample Full Regular Data CountV T (1, 4) N...  3.883771e-01
# 68  0.895323  Downsample Full Stemmed Data CountV F (1, 4) N...  3.468663e-01
# 52  0.895294  Downsample Full Stemmed Data CountV T (1, 3) N...  3.958413e-01
# 60  0.895239  Downsample Full Stemmed Data CountV F (1, 2) N...  3.685828e-01
# 56  0.893939  Downsample Full Stemmed Data CountV T (1, 4) N...  3.842915e-01
# 49  0.891590  Downsample Full Stemmed Data CountV T (1, 2) e...  3.679179e-01
# 61  0.891396  Downsample Full Stemmed Data CountV F (1, 2) e...  3.763543e-01
# 65  0.890607  Downsample Full Stemmed Data CountV F (1, 3) e...  3.389007e-01
# 53  0.890073  Downsample Full Stemmed Data CountV T (1, 3) e...  3.482388e-01
# 69  0.890064  Downsample Full Stemmed Data CountV F (1, 4) e...  3.565108e-01
# 13  0.889895  Downsample Full Regular Data CountV F (1, 2) e...  3.866141e-01
# 17  0.888916  Downsample Full Regular Data CountV F (1, 3) e...  3.653432e-01
# 57  0.888795  Downsample Full Stemmed Data CountV T (1, 4) e...  3.322621e-01
# 1   0.888439  Downsample Full Regular Data CountV T (1, 2) e...  3.926785e-01
# 21  0.888216  Downsample Full Regular Data CountV F (1, 4) e...  3.389751e-01
# 5   0.887582  Downsample Full Regular Data CountV T (1, 3) e...  3.501576e-01
# 9   0.886528  Downsample Full Regular Data CountV T (1, 4) e...  3.297834e-01
# 36  0.886161  Downsample Full Regular Data TFIDV F (1, 2) No...  4.963524e-01
# 24  0.884781  Downsample Full Regular Data TFIDV T (1, 2) No...  4.869956e-01
# 84  0.884367  Downsample Full Stemmed Data TFIDV F (1, 2) No...  4.753003e-01
# 72  0.883028  Downsample Full Stemmed Data TFIDV T (1, 2) No...  4.951464e-01
# 40  0.878766  Downsample Full Regular Data TFIDV F (1, 3) No...  5.339446e-01
# 31  0.878318  Downsample Full Regular Data TFIDV T (1, 3) en...  4.500302e-03
# ..       ...                                                ...           ...
# 42  0.872032  Downsample Full Regular Data TFIDV F (1, 3) No...  4.506122e-04
# 30  0.872032  Downsample Full Regular Data TFIDV T (1, 3) No...  4.506122e-04
# 62  0.871758  Downsample Full Stemmed Data CountV F (1, 2) N...  3.711246e-02
# 50  0.871758  Downsample Full Stemmed Data CountV T (1, 2) N...  3.711246e-02
# 86  0.871758  Downsample Full Stemmed Data TFIDV F (1, 2) No...  3.711246e-02
# 74  0.871758  Downsample Full Stemmed Data TFIDV T (1, 2) No...  3.711246e-02
# 44  0.871705  Downsample Full Regular Data TFIDV F (1, 4) No...  5.542042e-01
# 66  0.871240  Downsample Full Stemmed Data CountV F (1, 3) N...  4.313919e-04
# 90  0.871240  Downsample Full Stemmed Data TFIDV F (1, 3) No...  4.313919e-04
# 54  0.871240  Downsample Full Stemmed Data CountV T (1, 3) N...  4.313919e-04
# 78  0.871240  Downsample Full Stemmed Data TFIDV T (1, 3) No...  4.313919e-04
# 41  0.871186  Downsample Full Regular Data TFIDV F (1, 3) en...  5.574889e-01
# 10  0.871127  Downsample Full Regular Data CountV T (1, 4) N...  8.370916e-07
# 46  0.871127  Downsample Full Regular Data TFIDV F (1, 4) No...  8.370916e-07
# 34  0.871127  Downsample Full Regular Data TFIDV T (1, 4) No...  8.370916e-07
# 22  0.871127  Downsample Full Regular Data CountV F (1, 4) N...  8.370916e-07
# 82  0.870866  Downsample Full Stemmed Data TFIDV T (1, 4) No...  7.910352e-06
# 58  0.870866  Downsample Full Stemmed Data CountV T (1, 4) N...  7.910352e-06
# 70  0.870866  Downsample Full Stemmed Data CountV F (1, 4) N...  7.910352e-06
# 94  0.870866  Downsample Full Stemmed Data TFIDV F (1, 4) No...  7.910352e-06
# 29  0.870668  Downsample Full Regular Data TFIDV T (1, 3) en...  5.310918e-01
# 32  0.870540  Downsample Full Regular Data TFIDV T (1, 4) No...  5.581667e-01
# 92  0.870528  Downsample Full Stemmed Data TFIDV F (1, 4) No...  5.066971e-01
# 80  0.870320  Downsample Full Stemmed Data TFIDV T (1, 4) No...  5.464154e-01
# 89  0.870216  Downsample Full Stemmed Data TFIDV F (1, 3) en...  9.999999e-01
# 77  0.869818  Downsample Full Stemmed Data TFIDV T (1, 3) en...  9.999999e-01
# 45  0.869674  Downsample Full Regular Data TFIDV F (1, 4) en...  5.508108e-01
# 33  0.868325  Downsample Full Regular Data TFIDV T (1, 4) en...  5.484891e-01
# 93  0.867309  Downsample Full Stemmed Data TFIDV F (1, 4) en...  1.000000e+00
# 81  0.866298  Downsample Full Stemmed Data TFIDV T (1, 4) en...  1.000000e+00
#
# [96 rows x 3 columns]
